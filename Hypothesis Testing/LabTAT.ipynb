# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm

# %%
df=pd.read_csv("/content/drive/MyDrive/ExcelR/Assignment/Hypothesis testing/LabTAT.csv")

# %%
df.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
sns.distplot(df["Laboratory 1"])
sns.distplot(df["Laboratory 2"])
sns.distplot(df["Laboratory 3"])
sns.distplot(df["Laboratory 4"])
plt.legend('Laboratory 1'	,'Laboratory 2'	,'Laboratory 3'	,'Laboratory 4')
# Out:
# <ipython-input-5-e1c8a794592b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Laboratory 1"])
# <ipython-input-5-e1c8a794592b>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Laboratory 2"])
# <ipython-input-5-e1c8a794592b>:3: UserWarning:
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pvalue=stats.f_oneway(df.iloc[:,0],df.iloc[:,1],df.iloc[:,2],df.iloc[:,3])
pvalue
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
pvalue[1]
# Out:
# 2.1156708949992414e-57

# %% [markdown]
# P value is greater than alpha value hence HO is accepted
